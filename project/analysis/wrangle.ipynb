# %%
# Main code
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import re

def parse_order_info(order_info, player_name):
    order_list = re.findall(r"\[(.*?)\]", order_info)[0].split(", ")
    position = 1
    for i in range(len(order_list)):
        if player_name in order_list[i]:
            score = re.findall(r"\((.*?)\)", order_list[i])[0]
            position = i + 1
            break
    return score, position



def parse_gamelog(log_str):
    games = re.findall(r"Game started.*?Final results.*?\n", log_str, re.DOTALL)

    games_data = []
    hands_data = []

    for game_index, game in enumerate(games):
        try:
            player_name = re.findall(r"\[(.*?)\ ", re.findall(r"Players.*?\n", game)[0])[0]

            hands = re.findall(r"Round:.*?Cowboy: Score.*?\n", game, re.DOTALL)

            
            final_info = re.findall(r"Final results:.*?\n", game)[0]
            south_info = re.findall(r"Round: 4.*?]", game, re.DOTALL)
            if south_info:
                south_info = south_info[0]
            else:
                # when the game have no South rounds
                south_info = final_info

            south_score, south_position = parse_order_info(south_info, player_name)
            final_score, final_position = parse_order_info(final_info, player_name)

            games_data.append([game_index, south_score, final_score, south_position, final_position])

            for hand in hands:
                result = re.findall(r"Cowboy: Score.*?\n", hand)[0]
                score, score_diff, play_state, state_index = re.findall(r"Score: (.*?) Score difference: (.*?) Play State: (.*?) Latest change index: (.*?)\n", result)[0]

                meld_times = len(re.findall(r"With hand:", hand))
                reached = bool(re.findall(r"Go for it!", hand))

                is_dealer = player_name == re.findall(r"Dealer: (.*) ", hand)[0]

                hands_data.append([score, score_diff, play_state, state_index, meld_times, reached, is_dealer, game_index, final_position])
        
        except Exception as e:
            print(e)
    
    games_col = ['game_index',
     'south_score',
     'final_score',
     'south_position',
     'final_position']
    hands_col = ['score',
     'score_diff',
     'play_state',
     'state_index',
     'meld_times',
     'reached',
     'is_dealer',
     'game_index',
     'final_position',
    ]
    games_df = pd.DataFrame(data=np.array(games_data), columns=games_col)
    hands_df = pd.DataFrame(data=np.array(hands_data), columns=hands_col)
    return games_df, hands_df

# %%
# exec
log_files = ["gamelog.txt", "gamelog1.txt", "gamelog2.txt"] # change this
games_df_list = []
hands_df_list = []

for filename in log_files:
    with open("../"+filename) as f:
        log_str = f.read()
        games_df, hands_df = parse_gamelog(log_str)
        games_df_list.append(games_df)
        hands_df_list.append(hands_df)
        
# Change file name here
games_df_filename = "games2"
hands_df_filename = "hands2"

pd.concat(games_df_list).to_csv(games_df_filename + ".csv")
pd.concat(hands_df_list).to_csv(hands_df_filename + ".csv")

# %% [markdown]
# ## Develop

# %%
origin_str = ""
with open("../gamelog.txt") as f:
    origin_str = f.read()

# %% [markdown]
# ## Get 1 game

# %%
test_str = origin_str[:50000]

# %%
re.findall(r"Final result.*\n", test_str)
# Out:
# ['Final results: [ラークマイルド (52,700) 63.0, xelnaga (34,300) 14.0, 名字和JJ一樣長 (13,000) -27.0, きゅんさん (0) -50.0]\n',
#  'Final results: [ぽんこっこ (38,000) 48.0, 「のばら」２ (27,300) 7.0, LAS (19,200) -21.0, 名字和JJ一樣長 (15,500) -34.0]\n',
#  'Final results: [342g (55,300) 65.0, サムエル慶次 (26,700) 7.0, 名字和JJ一樣長 (22,000) -18.0, JamesROF (-4,000) -54.0]\n']

# %%
print(origin_str[:500])
# Out:
# nohup: ignoring input
# 2019-02-06 15:48:10 INFO: AI: 0.3.2, first_version
# 2019-02-06 15:48:10 INFO: Successfully authenticated
# 2019-02-06 15:48:10 INFO: Player has 二段 rank and 1474.78 rate
# 2019-02-06 15:48:10 INFO: Looking for the game...
# 2019-02-06 15:48:11 INFO: Game settings:
# 2019-02-06 15:48:11 INFO: Aka dora: True
# 2019-02-06 15:48:11 INFO: Open tanyao: True
# 2019-02-06 15:48:11 INFO: Game type: hanchan
# 2019-02-06 15:48:11 INFO: Game started
# 2019-02-06 15:48:11 INFO: Log: http://tenhou.net/0/?

# %%
games = re.findall(r"Game started.*?Final results.*?\n", test_str, re.DOTALL)
len(games)
# Out:
# 3

# %%
test_game = games[0]

# %%
print(test_game)
# Out:
# Game started
# 2019-02-06 15:48:11 INFO: Log: http://tenhou.net/0/?log=2019020700gm-0089-0000-1a7bf310&tw=3
# 2019-02-06 15:48:11 INFO: Players: [名字和JJ一樣長 (二段), ラークマイルド (四段), xelnaga (初段), きゅんさん (三段)]
# 2019-02-06 15:48:15 INFO: Cowboy: Score: 25000 Score difference: 0 Play State: PREPARING Latest change index: 0
# 2019-02-06 15:48:15 INFO: Round: 0, Honba: 0, Dora Indicators: 6p
# 2019-02-06 15:48:15 INFO: Players: [ラークマイルド (25,000), xelnaga (25,000), きゅんさん (25,000), 名字和JJ一樣長 (25,000)]
# 2019-02-06 15:48:15 INFO: Dealer: ラークマイルド (25,000)
# 2019-02-06 15:48:15 INFO: Round  wind: East
# 2019-02-06 15:48:15 INFO: Player wind: North
# 2019-02-06 15:48:29 INFO: Shanten: 4
# 2019-02-06 15:48:50 INFO: Shanten: 3
# 2019-02-06 15:48:58 INFO: Shanten: 2
# 2019-02-06 15:49:12 INFO: Meld: Type: chi, Tiles: 456m [14, 18, 20] by 0
# 2019-02-06 15:49:12 INFO: With hand: 4567m6p378s22266z + 6m
# 2019-02-06 15:49:12 INFO: Discard tile after called meld: 3s
# 2019-02-06 15:49:42 INFO: Meld: Type: chi, Tiles: 678m [23, 25, 29] by 0
# 2019-02-06 15:49:42 INFO: With hand: 677m78s22266z + 8m [456m]
# 2019-02-06 15:49:42 INFO: Discard tile after called meld: 7m
# 2019-02-06 15:49:50 INFO: Set the player's state from PREPARING to PROACTIVE_GOODSHAPE
# 2019-02-06 15:49:50 INFO: Hand: 2p78s22266z
# 2019-02-06 15:49:50 INFO: Outs: 69s 5
# 2019-02-06 15:50:08 INFO: Shanten: -1
# 2019-02-06 15:50:35 INFO: Meld: Type: pon, Tiles: 666z [128, 129, 130] by 0
# 2019-02-06 15:50:35 INFO: With hand: 78s22266z + 6z , 678m]
# 2019-02-06 15:50:35 INFO: Discard tile after called meld: 2z
# 2019-02-06 16:08:26 INFO: Shanten: 0
# 2019-02-06 16:08:26 INFO: Set the player's state from PREPARING to PROACTIVE_BADSHAPE
# 2019-02-06 16:08:26 INFO: Hand: 119m456p44s777z
# 2019-02-06 16:08:26 INFO: Outs: 1m4s 4
# 2019-02-06 16:08:36 INFO: Cowboy: Score: 19000 Score difference: -2000 Play State: PROACTIVE_BADSHAPE Latest change index: 8
# 2019-02-06 16:08:36 INFO: Round: 7, Honba: 0, Dora Indicators: 3p
# 2019-02-06 16:08:36 INFO: Players: [ラークマイルド (40,700), xelnaga (37,300), 名字和JJ一樣長 (19,000), きゅんさん (3,000)]
# 2019-02-06 16:08:36 INFO: Dealer: 名字和JJ一樣長 (19,000)
# 2019-02-06 16:08:36 INFO: Round  wind: South
# 2019-02-06 16:08:36 INFO: Player wind: East
# 2019-02-06 16:08:37 INFO: Shanten: 3
# 2019-02-06 16:08:59 INFO: Shanten: 2
# 2019-02-06 16:09:18 INFO: Meld: Type: pon, Tiles: 222z [112, 114, 115] by 2
# 2019-02-06 16:09:24 INFO: Shanten: 1
# 2019-02-06 16:09:39 INFO: Shanten: 1
# 2019-02-06 16:09:49 INFO: Meld: Type: pon, Tiles: 444s [84, 86, 87] by 2
# 2019-02-06 16:10:20 INFO: Riichi called by 1 player
# 2019-02-06 16:10:32 INFO: Meld: Type: chi, Tiles: 678s [94, 96, 101] by 0
# 2019-02-06 16:10:32 INFO: With hand: 24m34556777p268s + 7s
# 2019-02-06 16:10:32 INFO: Discard tile after called meld: 2s
# 2019-02-06 16:10:40 INFO: Cowboy: Score: 13000.0 Score difference: -6000.0 Play State: PREPARING Latest change index: 0
# 2019-02-06 16:10:40 INFO: Final results: [ラークマイルド (52,700) 63.0, xelnaga (34,300) 14.0, 名字和JJ一樣長 (13,000) -27.0, きゅんさん (0) -50.0]

# %%
test_hands = re.findall(r"Round:.*?Cowboy: Score.*?\n", test_game, re.DOTALL)
len(test_hands)
# Out:
# 9

# %%
test_hand = test_hands[0]

# %%
print(test_hand)
# Out:
# Round: 0, Honba: 0, Dora Indicators: 6p
# 2019-02-06 15:48:15 INFO: Players: [ラークマイルド (25,000), xelnaga (25,000), きゅんさん (25,000), 名字和JJ一樣長 (25,000)]
# 2019-02-06 15:48:15 INFO: Dealer: ラークマイルド (25,000)
# 2019-02-06 15:48:15 INFO: Round  wind: East
# 2019-02-06 15:48:15 INFO: Player wind: North
# 2019-02-06 15:48:29 INFO: Shanten: 4
# 2019-02-06 15:48:50 INFO: Shanten: 3
# 2019-02-06 15:48:58 INFO: Shanten: 2
# 2019-02-06 15:49:12 INFO: Meld: Type: chi, Tiles: 456m [14, 18, 20] by 0
# 2019-02-06 15:49:12 INFO: With hand: 4567m6p378s22266z + 6m
# 2019-02-06 15:49:12 INFO: Discard tile after called meld: 3s
# 2019-02-06 15:49:42 INFO: Meld: Type: chi, Tiles: 678m [23, 25, 29] by 0
# 2019-02-06 15:49:42 INFO: With hand: 677m78s22266z + 8m [456m]
# 2019-02-06 15:49:42 INFO: Discard tile after called meld: 7m
# 2019-02-06 15:49:50 INFO: Set the player's state from PREPARING to PROACTIVE_GOODSHAPE
# 2019-02-06 15:49:50 INFO: Hand: 2p78s22266z
# 2019-02-06 15:49:50 INFO: Outs: 69s 5
# 2019-02-06 15:50:08 INFO: Shanten: -1
# 2019-02-06 15:50:35 INFO: Meld: Type: pon, Tiles: 666z [128, 129, 130] by 0
# 2019-02-06 15:50:35 INFO: With hand: 78s22266z + 6z , 678m]
# 2019-02-06 15:50:35 INFO: Discard tile after called meld: 2z
# 2019-02-06 15:51:28 INFO: Meld: Type: chi, Tiles: 789p [60, 67, 69] by 2
# 2019-02-06 15:51:41 INFO: Cowboy: Score: 26100 Score difference: 1100 Play State: PROACTIVE_GOODSHAPE Latest change index: 8

# %%
test_result = re.findall(r"Cowboy: Score.*?\n", test_hand)[0]

# %%
test_result
# Out:
# 'Cowboy: Score: 26100 Score difference: 1100 Play State: PROACTIVE_GOODSHAPE Latest change index: 8\n'

# %%
meld_times = len(re.findall(r"With hand:", test_hand))
meld_times
# Out:
# 3

# %%
reached = bool(re.findall(r"Go for it!", test_hand))
reached
# Out:
# False

# %%
south_info = re.findall(r"Round: 4.*?]", test_game, re.DOTALL)[0]

# %%
final_info = re.findall(r"Final results:.*?\n", test_game)[0]

# %%
order_info = re.findall(r"\[.*?\]", south_info)[0]

# %%
order_info[1:-1].split(", ")
# Out:
# ['ラークマイルド (33,300)', '名字和JJ一樣長 (26,100)', 'xelnaga (24,700)', 'きゅんさん (15,900)']

# %%
player_name = re.findall(r"\[.*?\(", re.findall(r"Players.*?\n", test_game)[0])[0][1:-2]

# %%
position = 1
order_list = order_info.split(", ")
for i in range(len(order_list)):
    if player_name in order_list[i]:
        position = i + 1
        break

# %%
position
# Out:
# 2

# %%
def parse_order_info(order_info, player_name):
    order_list = re.findall(r"\[(.*?)\]", order_info)[0].split(", ")
    position = 1
    for i in range(len(order_list)):
        if player_name in order_list[i]:
            score = re.findall(r"\((.*?)\)", order_list[i])[0]
            position = i + 1
            break
    return score, position

# %%
parse_order_info(final_info, player_name)
# Out:
# ('13,000', 3)

# %%
re.findall(r"Dealer: (.*) ", test_hand)
# Out:
# ['ラークマイルド']

# %%
is_dealer = player_name == re.findall(r"Dealer: (.*) ", test_hand)

# %%
test_result
# Out:
# 'Cowboy: Score: 26100 Score difference: 1100 Play State: PROACTIVE_GOODSHAPE Latest change index: 8\n'

# %%
re.findall(r"Score: (.*?) Score difference: (.*?) Play State: (.*?) Latest change index: (.*?)\n", test_result)
# Out:
# [('26100', '1100', 'PROACTIVE_GOODSHAPE', '8')]

# %%
score, score_diff, play_state, state_index = re.findall(r"Score: (.*?) Score difference: (.*?) Play State: (.*?) Latest change index: (.*?)\n", test_result)[0]

# %%
player_name = re.findall(r"\[(.*?)\ ", re.findall(r"Players.*?\n", test_game)[0])[0]

# %%
games = re.findall(r"Game started.*?Final results.*?\n", test_str, re.DOTALL)

games_data = []
hands_data = []

for game_index, game in enumerate(games):
    player_name = re.findall(r"\[(.*?)\ ", re.findall(r"Players.*?\n", game)[0])[0]
    
    hands = re.findall(r"Round:.*?Cowboy: Score.*?\n", test_game, re.DOTALL)
    
    south_info = re.findall(r"Round: 4.*?]", game, re.DOTALL)[0]
    final_info = re.findall(r"Final results:.*?\n", game)[0]
    south_score, south_position = parse_order_info(south_info, player_name)
    final_score, final_position = parse_order_info(final_info, player_name)
    
    games_data.append([game_index, south_score, final_score, south_position, final_position])
    
    for hand in hands:
        result = re.findall(r"Cowboy: Score.*?\n", hand)[0]
        score, score_diff, play_state, state_index = re.findall(r"Score: (.*?) Score difference: (.*?) Play State: (.*?) Latest change index: (.*?)\n", result)[0]
        
        meld_times = len(re.findall(r"With hand:", hand))
        reached = bool(re.findall(r"Go for it!", hand))
        
        is_dealer = player_name == re.findall(r"Dealer: (.*) ", hand)[0]
        
        hands_data.append([score, score_diff, play_state, state_index, meld_times, reached, is_dealer, game_index])

# %%
games_col = ['game_index',
 'south_score',
 'final_score',
 'south_position',
 'final_position']

# %%
hands_col = ['score',
 'score_diff',
 'play_state',
 'state_index',
 'meld_times',
 'reached',
 'is_dealer',
 'game_index']

# %%
games_df = pd.DataFrame(data=np.array(games_data), columns=games_col)

# %%
games_df
# Out:
#   game_index south_score final_score south_position final_position
# 0          0      26,100      13,000              2              3
# 1          1         700      15,500              4              4
# 2          2      25,000      22,000              3              3

# %%
def parse_order_info(order_info, player_name):
    order_list = re.findall(r"\[(.*?)\]", order_info)[0].split(", ")
    position = 1
    for i in range(len(order_list)):
        if player_name in order_list[i]:
            score = re.findall(r"\((.*?)\)", order_list[i])[0]
            position = i + 1
            break
    return score, positionhands_df = pd.DataFrame(data=np.array(hands_data), columns=hands_col)
hands_df
# Out:
#       score score_diff           play_state state_index meld_times reached  \
# 0     26100       1100  PROACTIVE_GOODSHAPE           8          3   False
# 1     26100          0              DEFENCE           3          0   False
# 2     26100          0              DEFENCE           4          0   False
# 3     26100          0              DEFENCE           4          1   False
# 4     24100      -2000              DEFENCE          12          0   False
# 5     24100          0              DEFENCE           4          0   False
# 6     21000      -3100              DEFENCE          10          1   False
# 7     19000      -2000   PROACTIVE_BADSHAPE           8          1   False
# 8   13000.0    -6000.0            PREPARING           0          1   False
# 9     26100       1100  PROACTIVE_GOODSHAPE           8          3   False
# 10    26100          0              DEFENCE           3          0   False
# 11    26100          0              DEFENCE           4          0   False
# 12    26100          0              DEFENCE           4          1   False
# 13    24100      -2000              DEFENCE          12          0   False
# 14    24100          0              DEFENCE           4          0   False
# 15    21000      -3100              DEFENCE          10          1   False
# 16    19000      -2000   PROACTIVE_BADSHAPE           8          1   False
# 17  13000.0    -6000.0            PREPARING           0          1   False
# 18    26100       1100  PROACTIVE_GOODSHAPE           8          3   False
# 19    26100          0              DEFENCE           3          0   False
# 20    26100          0              DEFENCE           4          0   False
# 21    26100          0              DEFENCE           4          1   False
# 22    24100      -2000              DEFENCE          12          0   False
# 23    24100          0              DEFENCE           4          0   False
# 24    21000      -3100              DEFENCE          10          1   False
# 25    19000      -2000   PROACTIVE_BADSHAPE           8          1   False
# 26  13000.0    -6000.0            PREPARING           0          1   False
#
#    is_dealer game_index
# 0      False          0
# 1      False          0
# 2      False          0
# 3       True          0
# 4      False          0
# 5      False          0
# 6      False          0
# 7      False          0
# 8       True          0
# 9      False          1
# 10     False          1
# 11     False          1
# 12      True          1
# 13     False          1
# 14     False          1
# 15     False          1
# 16     False          1
# 17      True          1
# 18     False          2
# 19     False          2
# 20     False          2
# 21      True          2
# 22     False          2
# 23     False          2
# 24     False          2
# 25     False          2
# 26      True          2

# %% [markdown]
# ## Functions

# %%
def parse_order_info(order_info, player_name):
    order_list = re.findall(r"\[(.*?)\]", order_info)[0].split(", ")
    position = 1
    for i in range(len(order_list)):
        if player_name in order_list[i]:
            score = re.findall(r"\((.*?)\)", order_list[i])[0]
            position = i + 1
            break
    return score, position



def parse_gamelog(log_str):
    games = re.findall(r"Game started.*?Final results.*?\n", log_str, re.DOTALL)

    games_data = []
    hands_data = []

    for game_index, game in enumerate(games):
        try:
            player_name = re.findall(r"\[(.*?)\ ", re.findall(r"Players.*?\n", game)[0])[0]

            hands = re.findall(r"Round:.*?Cowboy: Score.*?\n", game, re.DOTALL)

            
            final_info = re.findall(r"Final results:.*?\n", game)[0]
            south_info = re.findall(r"Round: 4.*?]", game, re.DOTALL)
            if south_info:
                south_info = south_info[0]
            else:
                # when the game have no South rounds
                south_info = final_info

            south_score, south_position = parse_order_info(south_info, player_name)
            final_score, final_position = parse_order_info(final_info, player_name)

            games_data.append([game_index, south_score, final_score, south_position, final_position])

            for hand in hands:
                result = re.findall(r"Cowboy: Score.*?\n", hand)[0]
                score, score_diff, play_state, state_index = re.findall(r"Score: (.*?) Score difference: (.*?) Play State: (.*?) Latest change index: (.*?)\n", result)[0]

                meld_times = len(re.findall(r"With hand:", hand))
                reached = bool(re.findall(r"Go for it!", hand))

                is_dealer = player_name == re.findall(r"Dealer: (.*) ", hand)[0]

                hands_data.append([score, score_diff, play_state, state_index, meld_times, reached, is_dealer, game_index, final_position])
        
        except Exception as e:
            print(e)
    
    games_col = ['game_index',
     'south_score',
     'final_score',
     'south_position',
     'final_position']
    hands_col = ['score',
     'score_diff',
     'play_state',
     'state_index',
     'meld_times',
     'reached',
     'is_dealer',
     'game_index',
     'final_position',
    ]
    games_df = pd.DataFrame(data=np.array(games_data), columns=games_col)
    hands_df = pd.DataFrame(data=np.array(hands_data), columns=hands_col)
    return games_df, hands_df

# %%
games_df, hands_df = parse_gamelog(origin_str)

# %%
gamelog2 = ""
with open("../gamelog2.txt") as f:
    gamelog2 = f.read()

# %%
games_df2, hands_df2 = parse_gamelog(gamelog2)

# %%
pd.concat([games_df, games_df2]).to_csv("games1.csv")

# %%
pd.concat([hands_df, hands_df2]).to_csv("hands1.csv")

# %%
hands_df
# Out:
#        score score_diff           play_state state_index meld_times reached  \
# 0      26100       1100  PROACTIVE_GOODSHAPE           8          3   False
# 1      26100          0              DEFENCE           3          0   False
# 2      26100          0              DEFENCE           4          0   False
# 3      26100          0              DEFENCE           4          1   False
# 4      24100      -2000              DEFENCE          12          0   False
# 5      24100          0              DEFENCE           4          0   False
# 6      21000      -3100              DEFENCE          10          1   False
# 7      19000      -2000   PROACTIVE_BADSHAPE           8          1   False
# 8    13000.0    -6000.0            PREPARING           0          1   False
# 9      25000          0            PREPARING           0          0   False
# 10     13000     -12000   PROACTIVE_BADSHAPE           6          1   False
# 11     11500      -1500              DEFENCE           9          1   False
# 12     10200      -1300            PREPARING           0          0   False
# 13     10200          0            PREPARING           0          1   False
# 14      5200      -5000   REACTIVE_GOODSHAPE          13          0    True
# 15       700      -4500            PREPARING           0          2   False
# 16       700          0            PREPARING           0          0   False
# 17      8100       7400    REACTIVE_BADSHAPE          12          0   False
# 18      9100       1000  PROACTIVE_GOODSHAPE           4          1   False
# 19   15500.0     6400.0   PROACTIVE_BADSHAPE          12          0    True
# 20     33000       8000    REACTIVE_BADSHAPE          15          0    True
# 21     32000          0            PREPARING           0          0    True
# 22     32000          0            PREPARING           0          0    True
# 23     32000          0            PREPARING           0          0    True
# 24     25000          0            PREPARING           0          0    True
# 25     25000          0              DEFENCE           6          0   False
# 26     25000          0              DEFENCE          10          0   False
# 27     25000          0              DEFENCE          11          1   False
# 28     25000          0   PROACTIVE_BADSHAPE           8          2   False
# 29     25000          0              DEFENCE           1          0   False
# ..       ...        ...                  ...         ...        ...     ...
# 899    26500       1500   PROACTIVE_BADSHAPE          12          3   False
# 900    25500      -1000              DEFENCE           6          1   False
# 901    28500       3000  PROACTIVE_GOODSHAPE          12          1   False
# 902    27500      -1000            PREPARING           0          2   False
# 903    24500      -3000              DEFENCE           7          0   False
# 904    21000      -3500            PREPARING           0          1   False
# 905    21000          0            PREPARING           0          0   False
# 906    20600       -400              DEFENCE           7          1   False
# 907    20600          0   PROACTIVE_BADSHAPE          11          3   False
# 908  20600.0        0.0            PREPARING           0          1   False
# 909    24000      -1000              DEFENCE          15          1   False
# 910    20900      -3100  PROACTIVE_GOODSHAPE           3          0    True
# 911    20900          0            PREPARING           0          0   False
# 912    19400      -1500              DEFENCE           8          2   False
# 913    16200      -3200  PROACTIVE_GOODSHAPE          10          0    True
# 914    12200      -4000              DEFENCE          10          2   False
# 915     8900      -3300  PROACTIVE_GOODSHAPE           4          0    True
# 916     6900      -2000   PROACTIVE_BADSHAPE           4          0    True
# 917     8900       2000  PROACTIVE_GOODSHAPE           7          3   False
# 918     8900          0              DEFENCE          10          0   False
# 919     7400      -1500  PROACTIVE_GOODSHAPE           6          0    True
# 920   6400.0    -1000.0            PREPARING           0          0   False
# 921    25000          0   REACTIVE_GOODSHAPE           5          1   False
# 922    27000       2000            PREPARING           0          2   False
# 923    27000          0              DEFENCE           6          0   False
# 924    27000          0              DEFENCE           7          0   False
# 925    25000      -2000              DEFENCE           6          0   False
# 926    23000      -2000  PROACTIVE_GOODSHAPE           7          1   False
# 927    23000          0              DEFENCE           7          1   False
# 928  17000.0    -6000.0              DEFENCE          14          0   False
#
#     is_dealer game_index final_position
# 0       False          0              3
# 1       False          0              3
# 2       False          0              3
# 3        True          0              3
# 4       False          0              3
# 5       False          0              3
# 6       False          0              3
# 7       False          0              3
# 8        True          0              3
# 9        True          1              4
# 10      False          1              4
# 11      False          1              4
# 12      False          1              4
# 13      False          1              4
# 14      False          1              4
# 15      False          1              4
# 16       True          1              4
# 17      False          1              4
# 18      False          1              4
# 19      False          1              4
# 20      False          2              3
# 21      False          2              3
# 22      False          2              3
# 23      False          2              3
# 24      False          2              3
# 25      False          2              3
# 26       True          2              3
# 27      False          2              3
# 28      False          2              3
# 29      False          2              3
# ..        ...        ...            ...
# 899     False         83              3
# 900     False         83              3
# 901     False         83              3
# 902     False         83              3
# 903      True         83              3
# 904     False         83              3
# 905     False         83              3
# 906     False         83              3
# 907      True         83              3
# 908     False         83              3
# 909     False         84              4
# 910     False         84              4
# 911     False         84              4
# 912     False         84              4
# 913     False         84              4
# 914     False         84              4
# 915     False         84              4
# 916      True         84              4
# 917     False         84              4
# 918     False         84              4
# 919     False         84              4
# 920      True         84              4
# 921     False         85              3
# 922     False         85              3
# 923     False         85              3
# 924      True         85              3
# 925     False         85              3
# 926     False         85              3
# 927     False         85              3
# 928      True         85              3
#
# [929 rows x 9 columns]

# %%
for i in re.findall(r"(http.*)\n", origin_str):
    print(i)
# Out:
# http://tenhou.net/0/?log=2019020700gm-0089-0000-1a7bf310&tw=3
# http://tenhou.net/0/?log=2019020701gm-0089-0000-e0fa7774&tw=0
# http://tenhou.net/0/?log=2019020701gm-0089-0000-f9c7cdc1&tw=2
# http://tenhou.net/0/?log=2019020702gm-0089-0000-e2f3301d&tw=1
# http://tenhou.net/0/?log=2019020702gm-0089-0000-6712678b&tw=3
# http://tenhou.net/0/?log=2019020703gm-0089-0000-0ddb358f&tw=0
# http://tenhou.net/0/?log=2019020703gm-0089-0000-08012e66&tw=3
# http://tenhou.net/0/?log=2019020704gm-0089-0000-6bde1bb2&tw=3
# http://tenhou.net/0/?log=2019020704gm-0089-0000-468c3aa9&tw=1
# http://tenhou.net/0/?log=2019020705gm-0089-0000-7da238fe&tw=3
# http://tenhou.net/0/?log=2019020705gm-0089-0000-4e960f42&tw=2
# http://tenhou.net/0/?log=2019020706gm-0089-0000-530f6c59&tw=1
# http://tenhou.net/0/?log=2019020706gm-0089-0000-176939ed&tw=1
# http://tenhou.net/0/?log=2019020706gm-0089-0000-79253a84&tw=3
# http://tenhou.net/0/?log=2019020707gm-0089-0000-2f7a0fcf&tw=3
# http://tenhou.net/0/?log=2019020707gm-0089-0000-169571a3&tw=1
# http://tenhou.net/0/?log=2019020708gm-0089-0000-dc9ed77e&tw=0
# http://tenhou.net/0/?log=2019020708gm-0089-0000-7b528b6c&tw=3
# http://tenhou.net/0/?log=2019020708gm-0089-0000-770ca081&tw=3
# http://tenhou.net/0/?log=2019020709gm-0089-0000-c438d554&tw=3
# http://tenhou.net/0/?log=2019020709gm-0089-0000-6be5c35b&tw=2
# http://tenhou.net/0/?log=2019020710gm-0089-0000-2c26ef08&tw=1
# http://tenhou.net/0/?log=2019020710gm-0089-0000-26dff6e2&tw=0
# http://tenhou.net/0/?log=2019020711gm-0089-0000-47dfe04e&tw=0
# http://tenhou.net/0/?log=2019020712gm-0089-0000-6f80963c&tw=3
# http://tenhou.net/0/?log=2019020712gm-0089-0000-6b68de25&tw=3
# http://tenhou.net/0/?log=2019020713gm-0089-0000-13f0455b&tw=2
# http://tenhou.net/0/?log=2019020713gm-0089-0000-36a5b121&tw=0
# http://tenhou.net/0/?log=2019020714gm-0089-0000-6f10e4e4&tw=0
# http://tenhou.net/0/?log=2019020714gm-0089-0000-4963f18a&tw=0
# http://tenhou.net/0/?log=2019020715gm-0089-0000-300d9b1a&tw=2
# http://tenhou.net/0/?log=2019020715gm-0089-0000-00ad880d&tw=2
# http://tenhou.net/0/?log=2019020715gm-0089-0000-7e9087a5&tw=0
# http://tenhou.net/0/?log=2019020716gm-0089-0000-30a36c27&tw=2
# http://tenhou.net/0/?log=2019020716gm-0089-0000-78208f7f&tw=2
# http://tenhou.net/0/?log=2019020717gm-0089-0000-75eca3a9&tw=3
# http://tenhou.net/0/?log=2019020717gm-0089-0000-53d88621&tw=2
# http://tenhou.net/0/?log=2019020718gm-0089-0000-5384f4fa&tw=0
# http://tenhou.net/0/?log=2019020718gm-0089-0000-97ca52d3&tw=3
# http://tenhou.net/0/?log=2019020719gm-0089-0000-3568ae00&tw=3
# http://tenhou.net/0/?log=2019020719gm-0089-0000-35716ef7&tw=1
# http://tenhou.net/0/?log=2019020719gm-0089-0000-c61b982c&tw=3
# http://tenhou.net/0/?log=2019020720gm-0089-0000-f92af1ed&tw=1
# http://tenhou.net/0/?log=2019020720gm-0089-0000-7001d756&tw=3
# http://tenhou.net/0/?log=2019020720gm-0089-0000-15b74f19&tw=3
# http://tenhou.net/0/?log=2019020721gm-0089-0000-393059b2&tw=0
# http://tenhou.net/0/?log=2019020721gm-0089-0000-7f981f42&tw=1
# http://tenhou.net/0/?log=2019020722gm-0089-0000-c0a6b683&tw=0
# http://tenhou.net/0/?log=2019020722gm-0089-0000-fe31756e&tw=1
# http://tenhou.net/0/?log=2019020722gm-0089-0000-cfd3b3e3&tw=1
# http://tenhou.net/0/?log=2019020723gm-0089-0000-a3cd2bb0&tw=2
# http://tenhou.net/0/?log=2019020723gm-0089-0000-b3e68824&tw=3
# http://tenhou.net/0/?log=2019020800gm-0089-0000-aef6b8ae&tw=0
# http://tenhou.net/0/?log=2019020800gm-0089-0000-d9636146&tw=1
# http://tenhou.net/0/?log=2019020801gm-0089-0000-8f3117e4&tw=1
# http://tenhou.net/0/?log=2019020801gm-0089-0000-b7a61700&tw=0
# http://tenhou.net/0/?log=2019020801gm-0089-0000-b3930eaa&tw=1
# http://tenhou.net/0/?log=2019020802gm-0089-0000-1cfc0443&tw=3
# http://tenhou.net/0/?log=2019020802gm-0089-0000-002c3abb&tw=1
# http://tenhou.net/0/?log=2019020803gm-0089-0000-ca72da42&tw=0
# http://tenhou.net/0/?log=2019020803gm-0089-0000-856dcdef&tw=2
# http://tenhou.net/0/?log=2019020804gm-0089-0000-54239535&tw=3
# http://tenhou.net/0/?log=2019020804gm-0089-0000-5c66c800&tw=0
# http://tenhou.net/0/?log=2019020804gm-0089-0000-2d3858fb&tw=0
# http://tenhou.net/0/?log=2019020805gm-0089-0000-864afe04&tw=3
# http://tenhou.net/0/?log=2019020805gm-0089-0000-e1296365&tw=1
# http://tenhou.net/0/?log=2019020806gm-0089-0000-44d3084c&tw=1
# http://tenhou.net/0/?log=2019020806gm-0089-0000-bfad384e&tw=3
# http://tenhou.net/0/?log=2019020807gm-0089-0000-e769912d&tw=2
# http://tenhou.net/0/?log=2019020807gm-0089-0000-5ba23428&tw=0
# http://tenhou.net/0/?log=2019020808gm-0089-0000-b7589262&tw=2
# http://tenhou.net/0/?log=2019020808gm-0089-0000-2cafcf73&tw=0
# http://tenhou.net/0/?log=2019020809gm-0089-0000-6f20dabb&tw=2
# http://tenhou.net/0/?log=2019020809gm-0089-0000-f3ed88a6&tw=3
# http://tenhou.net/0/?log=2019020810gm-0089-0000-d8592b24&tw=0
# http://tenhou.net/0/?log=2019020810gm-0089-0000-afa534f5&tw=2
# http://tenhou.net/0/?log=2019020810gm-0089-0000-95a2e44e&tw=3
# http://tenhou.net/0/?log=2019020811gm-0089-0000-c890ef7f&tw=0
# http://tenhou.net/0/?log=2019020811gm-0089-0000-05b8f201&tw=1
# http://tenhou.net/0/?log=2019020812gm-0089-0000-741c7345&tw=2
# http://tenhou.net/0/?log=2019020812gm-0089-0000-fd4b6223&tw=1
# http://tenhou.net/0/?log=2019020813gm-0089-0000-2c997751&tw=2
# http://tenhou.net/0/?log=2019020813gm-0089-0000-4c315e40&tw=2
# http://tenhou.net/0/?log=2019020814gm-0089-0000-889190e7&tw=2
# http://tenhou.net/0/?log=2019020814gm-0089-0000-859a6af5&tw=1
# http://tenhou.net/0/?log=2019020815gm-0089-0000-0f2ef038&tw=0
# http://tenhou.net/0/?log=2019020816gm-0089-0000-373dd8cb&tw=0
# http://tenhou.net/0/?log=2019020816gm-0089-0000-a6580be1&tw=2
# http://tenhou.net/0/?log=2019020816gm-0089-0000-268b40cc&tw=3
# http://tenhou.net/0/?log=2019020817gm-0089-0000-30a21efe&tw=3
# http://tenhou.net/0/?log=2019020818gm-0089-0000-bb5312c4&tw=1
